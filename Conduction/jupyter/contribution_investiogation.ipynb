# %%
using Plots, VegaLite, LaTeXStrings, QuadGK;

# %%
k = 1.38 * 10^-23;
T = 300;
hbar = 1.054571817*10^(-34);

a = hbar / k / T;

f1(omega) = hbar * omega / (exp(a * omega) - 1) / k / T^2
f2(omega) = hbar * omega / (exp(a * omega)) / k / T^2

range = 0:0.1:10
plot(f1.(range))
# plot!(f2.(range))
